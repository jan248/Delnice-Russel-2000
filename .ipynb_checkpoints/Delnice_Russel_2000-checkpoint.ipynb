# %%
import pandas as pd
import matplotlib.pyplot as plt



# %matplotlib inline

delnice = pd.read_csv('podatki.csv')

# %%
delnice
# Out:
#      Oznaka           Ime_podjetja   Cena  Sprememba_cene  \
# 0      FLWS      1-800 FLOWERS COM  13.64          -0.160
# 1      SRCE        1ST SOURCE CORP  50.71          -0.080
# 2       AHC          A H BELO CORP   2.90           0.009
# 3      AAON               AAON INC  50.85           0.840
# 4       AIR               AAR CORP  46.78           0.010
# ...     ...                    ...    ...             ...
# 1128   ZAGG               ZAGG INC   7.71          -0.280
# 1129   ZIOP  ZIOPHARM ONCOLOGY INC   4.55          -0.040
# 1130   ZIXI               ZIX CORP   7.73           0.215
# 1131   ZGNX            ZOGENIX INC  52.70           0.680
# 1132   ZUMZ             ZUMIEZ INC  33.97          -0.510
#
#      Sprememba_v_odstotkih PE_razmerje Stevilo_delnic Sprememba_do_danes
# 0                   -1.16%        24.8         478.5K             -5.93%
# 1                   -0.16%        14.3          32.2K             -2.26%
# 2                   +0.31%         4.9          27.5K             +2.84%
# 3                   +1.68%        53.0          95.0K             +2.91%
# 4                   +0.02%        17.9         162.1K             +3.73%
# ...                    ...         ...            ...                ...
# 1128                -3.50%        59.3         448.0K             -4.93%
# 1129                -0.87%         6.1           1.0M             -3.60%
# 1130                +2.86%          NM         820.1K            +13.94%
# 1131                +1.31%          NM         328.5K             +1.09%
# 1132                -1.49%        14.7         393.7K             -1.66%
#
# [1133 rows x 8 columns]

# %%
delnice.Stevilo_delnic = (delnice.Stevilo_delnic.replace(r'[KM]+$', '', regex=True).astype(float) * \
   ....:           delnice.Stevilo_delnic.str.extract(r'[\d\.]+([KM]+)', expand=False)
   ....:             .fillna(1)
   ....:             .replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
delnice['PE_razmerje'] = delnice['PE_razmerje'].replace('NM',0)

delnice
# Out:
#      Oznaka           Ime_podjetja   Cena  Sprememba_cene  \
# 0      FLWS      1-800 FLOWERS COM  13.64          -0.160
# 1      SRCE        1ST SOURCE CORP  50.71          -0.080
# 2       AHC          A H BELO CORP   2.90           0.009
# 3      AAON               AAON INC  50.85           0.840
# 4       AIR               AAR CORP  46.78           0.010
# ...     ...                    ...    ...             ...
# 1128   ZAGG               ZAGG INC   7.71          -0.280
# 1129   ZIOP  ZIOPHARM ONCOLOGY INC   4.55          -0.040
# 1130   ZIXI               ZIX CORP   7.73           0.215
# 1131   ZGNX            ZOGENIX INC  52.70           0.680
# 1132   ZUMZ             ZUMIEZ INC  33.97          -0.510
#
#      Sprememba_v_odstotkih PE_razmerje  Stevilo_delnic Sprememba_do_danes
# 0                   -1.16%        24.8        478500.0             -5.93%
# 1                   -0.16%        14.3         32200.0             -2.26%
# 2                   +0.31%         4.9         27500.0             +2.84%
# 3                   +1.68%        53.0         95000.0             +2.91%
# 4                   +0.02%        17.9        162100.0             +3.73%
# ...                    ...         ...             ...                ...
# 1128                -3.50%        59.3        448000.0             -4.93%
# 1129                -0.87%         6.1       1000000.0             -3.60%
# 1130                +2.86%           0        820100.0            +13.94%
# 1131                +1.31%           0        328500.0             +1.09%
# 1132                -1.49%        14.7        393700.0             -1.66%
#
# [1133 rows x 8 columns]

# %%
delnice['Sprememba_v_odstotkih'] = delnice['Sprememba_v_odstotkih'].map(lambda x: x.lstrip('+').rstrip('%'))
delnice['Sprememba_do_danes'] = delnice['Sprememba_do_danes'].map(lambda x: x.lstrip('+').rstrip('%'))

# %%
delnice['Cena'] = pd.to_numeric(delnice['Cena'],errors='coerce')
delnice['Sprememba_do_danes'] = pd.to_numeric(delnice['Sprememba_do_danes'],errors='coerce')
delnice['Sprememba_v_odstotkih'] = pd.to_numeric(delnice['Sprememba_v_odstotkih'],errors='coerce')
delnice['Stevilo_delnic'] = pd.to_numeric(delnice['Stevilo_delnic'],errors='coerce')
delnice['PE_razmerje'] = pd.to_numeric(delnice['PE_razmerje'],errors='coerce')

# %%
delnice['Stevilo_delnic'] = delnice['Stevilo_delnic']/10000
delnice
# Out:
#      Oznaka           Ime_podjetja   Cena  Sprememba_cene  \
# 0      FLWS      1-800 FLOWERS COM  13.64          -0.160
# 1      SRCE        1ST SOURCE CORP  50.71          -0.080
# 2       AHC          A H BELO CORP   2.90           0.009
# 3      AAON               AAON INC  50.85           0.840
# 4       AIR               AAR CORP  46.78           0.010
# ...     ...                    ...    ...             ...
# 1128   ZAGG               ZAGG INC   7.71          -0.280
# 1129   ZIOP  ZIOPHARM ONCOLOGY INC   4.55          -0.040
# 1130   ZIXI               ZIX CORP   7.73           0.215
# 1131   ZGNX            ZOGENIX INC  52.70           0.680
# 1132   ZUMZ             ZUMIEZ INC  33.97          -0.510
#
#       Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes
# 0                     -1.16         24.8           47.85               -5.93
# 1                     -0.16         14.3            3.22               -2.26
# 2                      0.31          4.9            2.75                2.84
# 3                      1.68         53.0            9.50                2.91
# 4                      0.02         17.9           16.21                3.73
# ...                     ...          ...             ...                 ...
# 1128                  -3.50         59.3           44.80               -4.93
# 1129                  -0.87          6.1          100.00               -3.60
# 1130                   2.86          0.0           82.01               13.94
# 1131                   1.31          0.0           32.85                1.09
# 1132                  -1.49         14.7           39.37               -1.66
#
# [1133 rows x 8 columns]

# %%
top_delnice = delnice['Sprememba_do_danes'] > 10
delnice[top_delnice]
# Out:
#      Oznaka             Ime_podjetja    Cena  Sprememba_cene  \
# 33     ACOR  ACORDA THERAPEUTICS INC    2.28          0.0200
# 40     AVAV        AEROVIRONMENT INC   69.71          1.1500
# 68     AMRC             AMERESCO INC   19.58          0.3500
# 83     AMPE    AMPIO PHARMACEUTICALS    0.69         -0.0300
# 106    AZPN     ASPEN TECHNOLOGY INC  136.20          5.0600
# ...     ...                      ...     ...             ...
# 1066    EGY        VAALCO ENERGY INC    2.54          0.2200
# 1072   VSTM             VERASTEM INC    1.80          0.0800
# 1076   VICR               VICOR CORP   51.43          0.1500
# 1102   WSTL  WESTELL TECHNOLOGIES IN    1.07          0.0653
# 1130   ZIXI                 ZIX CORP    7.73          0.2150
#
#       Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes
# 33                     0.88          0.0          190.00               11.76
# 40                     1.68         43.0           27.18               12.91
# 68                     1.82         27.6           27.78               11.89
# 83                    -4.17          0.0          120.00               18.34
# 106                    3.86         35.4           73.25               12.63
# ...                     ...          ...             ...                 ...
# 1066                   9.48         25.4           48.50               14.41
# 1072                   4.65          0.0         1060.00               34.33
# 1076                   0.29        107.1           22.02               10.08
# 1102                   6.53          0.0            6.30               19.01
# 1130                   2.86          0.0           82.01               13.94
#
# [43 rows x 8 columns]

# %%
slabe_delnice = delnice['Sprememba_do_danes'] < -20
delnice[slabe_delnice]
# Out:
#     Oznaka          Ime_podjetja   Cena  Sprememba_cene  \
# 162    BGG  BRIGGS & STRATTON CO   5.32           -0.23
# 240    CDE      COEUR MINING INC   6.40            0.11
# 812    PIR    PIER 1 IMPORTS INC   3.76           -0.12
# 994    TEN           TENNECO INC  10.26           -0.79
#
#      Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes
# 162                  -4.14          0.0           81.54              -20.12
# 240                   1.75          0.0          910.00              -20.79
# 812                  -3.09          0.0           41.99              -41.25
# 994                  -7.15          0.0          390.00              -21.68

# %%
pozitivne_delnice = delnice['PE_razmerje'] > 0
dobicek_delnice=delnice[pozitivne_delnice]
podcenjene_delnice = dobicek_delnice['PE_razmerje'] < 15
dobicek_delnice[podcenjene_delnice]
# Out:
#      Oznaka             Ime_podjetja   Cena  Sprememba_cene  \
# 1      SRCE          1ST SOURCE CORP  50.71         -0.0800
# 2       AHC            A H BELO CORP   2.90          0.0090
# 7      AXAS        ABRAXAS PETE CORP   0.35         -0.0045
# 13     ACCO         ACCO BRANDS CORP   8.69         -0.1500
# 16     SRCE          1ST SOURCE CORP  50.71         -0.0800
# ...     ...                      ...    ...             ...
# 1113   WTFC  WINTRUST FINANCIAL CORP  70.26         -0.0400
# 1118   WRLD    WORLD ACCEPTANCE CORP  87.12          0.0800
# 1122   WSFS      WSFS FINANCIAL CORP  42.74         -0.0700
# 1129   ZIOP    ZIOPHARM ONCOLOGY INC   4.55         -0.0400
# 1132   ZUMZ               ZUMIEZ INC  33.97         -0.5100
#
#       Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes
# 1                     -0.16         14.3            3.22               -2.26
# 2                      0.31          4.9            2.75                2.84
# 7                     -1.29          1.0          110.00               -1.71
# 13                    -1.70          9.1           37.68               -7.16
# 16                    -0.16         14.3            3.22               -2.26
# ...                     ...          ...             ...                 ...
# 1113                  -0.06         11.8           24.40               -0.90
# 1118                   0.09         13.9            4.34                0.83
# 1122                  -0.16         14.0           23.22               -2.84
# 1129                  -0.87          6.1          100.00               -3.60
# 1132                  -1.49         14.7           39.37               -1.66
#
# [261 rows x 8 columns]

# %%
delnice_nakup = delnice[(delnice.PE_razmerje < 15) & (delnice.PE_razmerje > 0) & (delnice.Sprememba_do_danes > 8)]
delnice_nakup
# Out:
#      Oznaka             Ime_podjetja   Cena  Sprememba_cene  \
# 113    AVEO  AVEO PHARMACEUTICALS IN   0.69          0.0059
# 582     KBH                  KB HOME  37.06          0.0600
# 974    SPRT          SUPPORT.COM INC   1.38          0.1100
# 1013   TRNX              TORNIER N V   1.07         -0.0900
#
#       Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes
# 113                    0.87          5.3           88.43                9.92
# 582                    0.16         14.8          370.00                8.14
# 974                    8.66          6.3           31.41               26.61
# 1013                  -7.76          0.1          210.00               17.95

# %%
dobicek_delnice[podcenjene_delnice]['PE_razmerje'].hist()

# %%
Stevilo_delnic = delnice['Stevilo_delnic']
st_delnic_rounded = round(Stevilo_delnic)
delnice['st_delnic_rounded'] = st_delnic_rounded
delnice
# Out:
#      Oznaka           Ime_podjetja   Cena  Sprememba_cene  \
# 0      FLWS      1-800 FLOWERS COM  13.64          -0.160
# 1      SRCE        1ST SOURCE CORP  50.71          -0.080
# 2       AHC          A H BELO CORP   2.90           0.009
# 3      AAON               AAON INC  50.85           0.840
# 4       AIR               AAR CORP  46.78           0.010
# ...     ...                    ...    ...             ...
# 1128   ZAGG               ZAGG INC   7.71          -0.280
# 1129   ZIOP  ZIOPHARM ONCOLOGY INC   4.55          -0.040
# 1130   ZIXI               ZIX CORP   7.73           0.215
# 1131   ZGNX            ZOGENIX INC  52.70           0.680
# 1132   ZUMZ             ZUMIEZ INC  33.97          -0.510
#
#       Sprememba_v_odstotkih  PE_razmerje  Stevilo_delnic  Sprememba_do_danes  \
# 0                     -1.16         24.8           47.85               -5.93
# 1                     -0.16         14.3            3.22               -2.26
# 2                      0.31          4.9            2.75                2.84
# 3                      1.68         53.0            9.50                2.91
# 4                      0.02         17.9           16.21                3.73
# ...                     ...          ...             ...                 ...
# 1128                  -3.50         59.3           44.80               -4.93
# 1129                  -0.87          6.1          100.00               -3.60
# 1130                   2.86          0.0           82.01               13.94
# 1131                   1.31          0.0           32.85                1.09
# 1132                  -1.49         14.7           39.37               -1.66
#
#       st_delnic_rounded
# 0                  48.0
# 1                   3.0
# 2                   3.0
# 3                  10.0
# 4                  16.0
# ...                 ...
# 1128               45.0
# 1129              100.0
# 1130               82.0
# 1131               33.0
# 1132               39.0
#
# [1133 rows x 9 columns]

# %%
delnice1 = delnice[delnice['Cena'] < 100]
delnice_po_ceni = delnice1.groupby('Cena')
povprecje_po_ceni = delnice_po_ceni.mean()
povprecje_delnice = povprecje_po_ceni[['Stevilo_delnic']]
povprecje_delnice.plot()

# %%
dobicek_delnice = delnice[(delnice['PE_razmerje'] > 0) & (delnice['Stevilo_delnic'] < 100)]
izguba_delnice = delnice[(delnice['PE_razmerje'] == 0) & (delnice['Stevilo_delnic'] < 100)]
ax = dobicek_delnice.plot.scatter(x='Stevilo_delnic', y='Cena', color='DarkBlue', label='Delnice z dobičkom')
izguba_delnice.plot.scatter(x='Stevilo_delnic', y='Cena', color='DarkGreen', label='Delnice z izgubo', ax=ax)
